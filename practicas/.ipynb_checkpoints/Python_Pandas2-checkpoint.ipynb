# %% [markdown]
# ![Logo ITQ](./img/logoitqv1.jpg)

# %% [markdown]
# Octavo Programa en Python
#
# # Python 1, Estructura de datos, + Pandas

# %% [markdown]
# ![Logo Python](./img/python_logo.png)

# %% [markdown]
# * Nombre: *Christian Zumárraga*
# * Fecha : **9-07-2026**
# * Repositorio: *[Link del repositorio de GitHub](https://github.com/Crishito/machine12026/blob/main/practicas/Python_Funciones.ipynb)*

# %%
# importar librerías para manejo de datos y operaciones numéricas
import pandas as pd
import numpy as np

# %%
# mostrar la versión de pandas instalada
pd.__version__
# Out:
# '3.0.3'

# %% [markdown]
# # Operaciones en pandas
#
# **Búsqueda**

# %%
# crear una matriz aleatoria y convertirla en un DataFrame
rand_matrix = np.random.randint(6, size=(2,3))
frame = pd.DataFrame(rand_matrix, columns=list('ABC'))

display(frame)
# Out:
#    A  B  C
# 0  2  5  1
# 1  3  0  5

# %%
# buscando columnas (DataFrame como dic, busca en claves)
'A' in frame
# Out:
# True

# %%
# buscando valores
display(frame.isin([3,2])) # --> mask de respuesta (valores que son 3 o 2)
# Out:
#       A      B      C
# 0  True  False  False
# 1  True  False  False

# %%
# Contar el número de ocurrencias
print(frame.isin([4]).values.sum())

# devuelve una máscara con valores True si el elemento es 4
display(frame.isin([4]))

print(frame.isin([4]).values)

# pandas es una capa alrededor de numpy
type(frame.isin([4]).values)
# Out:
# 0
#        A      B      C
# 0  False  False  False
# 1  False  False  False
# [[False False False]
#  [False False False]]
# numpy.ndarray

# %%
# Cuántos valores son >= 2
mask = frame >= 2
print(mask.values.sum())

display(mask)
# Out:
# 4
#       A      B      C
# 0  True   True  False
# 1  True  False   True

# %% [markdown]
# **Ordenación**

# %%
# crear una matriz aleatoria con índices mezclados
from random import shuffle

rand_matrix = np.random.randint(20, size=(5,4))

indices = list(range(5))
shuffle(indices) # mezcla indices

frame = pd.DataFrame(rand_matrix, columns=list('DACB'), index=indices)

display(frame)
# Out:
#     D   A   C   B
# 1  19   1   4   5
# 4  18  16  11  19
# 2   6   1   4   5
# 0  10   0   8  12
# 3   8  12   1   0

# %%
# ordenar por índice
display(frame.sort_index(ascending=False))
display(frame)
# Out:
#     D   A   C   B
# 4  18  16  11  19
# 3   8  12   1   0
# 2   6   1   4   5
# 1  19   1   4   5
# 0  10   0   8  12
#     D   A   C   B
# 1  19   1   4   5
# 4  18  16  11  19
# 2   6   1   4   5
# 0  10   0   8  12
# 3   8  12   1   0

# %%
#ordenar por columna
display(frame.sort_index(axis=1, ascending=False))
# Out:
#     D   C   B   A
# 1  19   4   5   1
# 4  18  11  19  16
# 2   6   4   5   1
# 0  10   8  12   0
# 3   8   1   0  12

# %%
# ordenar filas por valor en columna
display(frame.sort_values(by='A', ascending=True))
# Out:
#     D   A   C   B
# 0  10   0   8  12
# 1  19   1   4   5
# 2   6   1   4   5
# 3   8  12   1   0
# 4  18  16  11  19

# %%
# ordenar columnas por valor en fila
display(frame.sort_values(by=1, axis=1, ascending=True))
# Out:
#     A   C   B   D
# 1   1   4   5  19
# 4  16  11  19  18
# 2   1   4   5   6
# 0   0   8  12  10
# 3  12   1   0   8

# %%
# ordenar por valor en columna y guardar cambios
frame.sort_values(by='A', ascending=False, inplace=True)
display(frame)
# Out:
#     D   A   C   B
# 4  18  16  11  19
# 3   8  12   1   0
# 1  19   1   4   5
# 2   6   1   4   5
# 0  10   0   8  12

# %% [markdown]
# **Ranking**
#
# * Construir un ranking de valores

# %%
# mostrar el DataFrame
display(frame)
# Out:
#     D   A   C   B
# 4  18  16  11  19
# 3   8  12   1   0
# 1  19   1   4   5
# 2   6   1   4   5
# 0  10   0   8  12

# %%
# asignar rangos a los valores del DataFrame por fila
display(frame.rank(method='max', axis=1))
# Out:
#      D    A    C    B
# 4  3.0  2.0  1.0  4.0
# 3  3.0  4.0  2.0  1.0
# 1  4.0  1.0  2.0  3.0
# 2  4.0  1.0  2.0  3.0
# 0  3.0  1.0  2.0  4.0

# %%
# Imprimir los valores de la columna 'C' ordenados de mayor a menor
for x in frame.sort_values(by='C', ascending=False)['C'].values:
    print(x)
# Out:
# 11
# 8
# 4
# 4
# 1

# %% [markdown]
# # Operaciones
#
# Operaciones matemáticas entre objetos

# %%
# crear dos matrices aleatorias y convertirlas en DataFrames
matrixA = np.random.randint(100, size=(4,4))
matrixB = np.random.randint(100, size=(4,4))

frameA = pd.DataFrame(matrixA)
frameB = pd.DataFrame(matrixB)

display(frameA)
display(frameB)
# Out:
#     0   1   2   3
# 0  61  69  77  94
# 1  39  76  41  73
# 2  29  39  26  29
# 3  11  68  41  81
#     0   1   2   3
# 0   9  90  62  58
# 1  55  29  24   4
# 2  35  78  76  64
# 3  76  26  97   3

# %%
# sumar DataFrames usando operadores y métodos
display(frameA + frameB == frameA.add(frameB))

display(frameA + frameB)
# Out:
#       0     1     2     3
# 0  True  True  True  True
# 1  True  True  True  True
# 2  True  True  True  True
# 3  True  True  True  True
#     0    1    2    3
# 0  70  159  139  152
# 1  94  105   65   77
# 2  64  117  102   93
# 3  87   94  138   84

# %%
# restar DataFrames usando operadores y métodos
display(frameB - frameA == frameB.sub(frameA))

display(frameB - frameA)
# Out:
#       0     1     2     3
# 0  True  True  True  True
# 1  True  True  True  True
# 2  True  True  True  True
# 3  True  True  True  True
#     0   1   2   3
# 0 -52  21 -15 -36
# 1  16 -47 -17 -69
# 2   6  39  50  35
# 3  65 -42  56 -78

# %%
# si los DataFrames no son iguales, valor por defecto NaN
frameC = pd.DataFrame(np.random.randint(100, size=(3,3)))

display(frameA)
display(frameC)
display(frameC + frameA)
# Out:
#     0   1   2   3
# 0  61  69  77  94
# 1  39  76  41  73
# 2  29  39  26  29
# 3  11  68  41  81
#     0   1   2
# 0  45  50  54
# 1  70  82  60
# 2  90  90  83
#        0      1      2   3
# 0  106.0  119.0  131.0 NaN
# 1  109.0  158.0  101.0 NaN
# 2  119.0  129.0  109.0 NaN
# 3    NaN    NaN    NaN NaN

# %%
# especificar el valor por defecto con el argumento fill_value
display(frameA.add(frameC, fill_value=0))
# Out:
#        0      1      2     3
# 0  106.0  119.0  131.0  94.0
# 1  109.0  158.0  101.0  73.0
# 2  119.0  129.0  109.0  29.0
# 3   11.0   68.0   41.0  81.0

# %% [markdown]
# Operadores aritméticos solo válidos en elementos aceptables

# %%
# crear un DataFrame con valores de texto
frameD = pd.DataFrame({0: ['a','b'], 1: ['d','f']})

display(frameD)

# operación entre DataFrames con tipos incompatibles
# error al operar con DataFrames de tipos diferentes (números y texto)
frameA - frameD
# Out:
#    0  1
# 0  a  d
# 1  b  f
# ---------------------------------------------------------------------------
# ArrowNotImplementedError                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\arrow\array.py:1041, in ArrowExtensionArray._evaluate_op_method(self, other, op, arrow_funcs)
#    1040 try:
# -> 1041     result = pc_func(self._pa_array, other)
#    1042 except pa.ArrowNotImplementedError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\arrow\array.py:181, in <lambda>(x, y)
#     175         return result
#     177     ARROW_ARITHMETIC_FUNCS = {
#     178         "add": pc.add_checked,
#     179         "radd": lambda x, y: pc.add_checked(y, x),
#     180         "sub": pc.subtract_checked,
# --> 181         "rsub": lambda x, y: pc.subtract_checked(y, x),
#     182         "mul": pc.multiply_checked,
#     183         "rmul": lambda x, y: pc.multiply_checked(y, x),
#     184         "truediv": lambda x, y: pc.divide(*cast_for_truediv(x, y)),
#     185         "rtruediv": lambda x, y: pc.divide(*cast_for_truediv(y, x)),
#     186         "floordiv": lambda x, y: floordiv_compat(x, y),
#     187         "rfloordiv": lambda x, y: floordiv_compat(y, x),
#     188         "mod": NotImplemented,
#     189         "rmod": NotImplemented,
#     190         "divmod": NotImplemented,
#     191         "rdivmod": NotImplemented,
#     192         "pow": pc.power_checked,
#     193         "rpow": lambda x, y: pc.power_checked(y, x),
#     194     }
#     196 if TYPE_CHECKING:
#
# File ~\anaconda3\Lib\site-packages\pyarrow\compute.py:252, in _make_generic_wrapper.<locals>.wrapper(memory_pool, *args)
#     251     return Expression._call(func_name, list(args))
# --> 252 return func.call(args, None, memory_pool)
#
# File ~\anaconda3\Lib\site-packages\pyarrow\_compute.pyx:399, in pyarrow._compute.Function.call()
#
# File ~\anaconda3\Lib\site-packages\pyarrow\error.pxi:155, in pyarrow.lib.pyarrow_internal_check_status()
#
# File ~\anaconda3\Lib\site-packages\pyarrow\error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowNotImplementedError: Function 'subtract_checked' has no kernel matching input types (int32, large_string)
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 8
#       4 display(frameD)
#       6 # operación entre DataFrames con tipos incompatibles
#       7 # error al operar con DataFrames de tipos diferentes (números y texto)
# ----> 8 frameA - frameD
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:198, in OpsMixin.__sub__(self, other)
#     196 @unpack_zerodim_and_defer("__sub__")
#     197 def __sub__(self, other):
# --> 198     return self._arith_method(other, operator.sub)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9143, in DataFrame._arith_method(self, other, op)
#    9141 def _arith_method(self, other, op):
#    9142     if self._should_reindex_frame_op(other, op, 1, None, None):
# -> 9143         return self._arith_method_with_reindex(other, op)
#    9145     axis: Literal[1] = 1  # only relevant for Series other case
#    9146     other = ops.maybe_prepare_scalar_for_op(other, (self.shape[axis],))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9279, in DataFrame._arith_method_with_reindex(self, right, op)
#    9276     new_left.columns = cols
#    9277     new_right.columns = cols
# -> 9279 result = op(new_left, new_right)
#    9281 # Do the join on the columns instead of using left._align_for_op
#    9282 #  to avoid constructing two potentially large/sparse DataFrames
#    9283 join_columns = left.columns.join(right.columns, how="outer")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:198, in OpsMixin.__sub__(self, other)
#     196 @unpack_zerodim_and_defer("__sub__")
#     197 def __sub__(self, other):
# --> 198     return self._arith_method(other, operator.sub)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9151, in DataFrame._arith_method(self, other, op)
#    9148 self, other = self._align_for_op(other, axis, flex=True, level=None)
#    9150 with np.errstate(all="ignore"):
# -> 9151     new_data = self._dispatch_frame_op(other, op, axis=axis)
#    9152 return self._construct_result(new_data, other=other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9194, in DataFrame._dispatch_frame_op(self, right, func, axis)
#    9188     assert self.columns.equals(right.columns)
#    9189     # TODO: The previous assertion `assert right._indexed_same(self)`
#    9190     #  fails in cases with empty columns reached via
#    9191     #  _frame_arith_method_with_reindex
#    9192
#    9193     # TODO operate_blockwise expects a manager of the same type
# -> 9194     bm = self._mgr.operate_blockwise(
#    9195         right._mgr,
#    9196         array_op,
#    9197     )
#    9198     return self._constructor_from_mgr(bm, axes=bm.axes)
#    9200 elif isinstance(right, Series) and axis == 1:
#    9201     # axis=1 means we want to operate row-by-row
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1691, in BlockManager.operate_blockwise(self, other, array_op)
#    1687 def operate_blockwise(self, other: BlockManager, array_op) -> BlockManager:
#    1688     """
#    1689     Apply array_op blockwise with another (aligned) BlockManager.
#    1690     """
# -> 1691     return operate_blockwise(self, other, array_op)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\ops.py:65, in operate_blockwise(left, right, array_op)
#      63 res_blks: list[Block] = []
#      64 for lvals, rvals, locs, left_ea, right_ea, rblk in _iter_block_pairs(left, right):
# ---> 65     res_values = array_op(lvals, rvals)
#      66     if (
#      67         left_ea
#      68         and not right_ea
#      69         and hasattr(res_values, "reshape")
#      70         and not is_1d_only_ea_dtype(res_values.dtype)
#      71     ):
#      72         res_values = res_values.reshape(1, -1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:279, in arithmetic_op(left, right, op)
#     270 right = ensure_wrapped_if_datetimelike(right)
#     272 if (
#     273     should_extension_dispatch(left, right)
#     274     or isinstance(right, (Timedelta, BaseOffset, Timestamp))
#    (...)    277     # Timedelta/Timestamp and other custom scalars are included in the check
#     278     # because numexpr will fail on it, see GH#31457
# --> 279     res_values = op(left, right)
#     280 else:
#     281     # TODO we should handle EAs consistently and move this check before the if/else
#     282     # (https://github.com/pandas-dev/pandas/issues/41165)
#     283     # error: Argument 2 to "_bool_arith_check" has incompatible type
#     284     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
#     285     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\arrow\array.py:845, in ArrowExtensionArray.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#     843 def __array_ufunc__(self, ufunc: np.ufunc, method: str, *inputs, **kwargs):
#     844     # Need to wrap np.array results GH#62800
# --> 845     result = super().__array_ufunc__(ufunc, method, *inputs, **kwargs)
#     846     if type(self) is ArrowExtensionArray:
#     847         # Exclude ArrowStringArray
#     848         return type(self)._from_sequence(result)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\base.py:2705, in ExtensionArray.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2700 if any(
#    2701     isinstance(other, (ABCSeries, ABCIndex, ABCDataFrame)) for other in inputs
#    2702 ):
#    2703     return NotImplemented
# -> 2705 result = arraylike.maybe_dispatch_ufunc_to_dunder_op(
#    2706     self, ufunc, method, *inputs, **kwargs
#    2707 )
#    2708 if result is not NotImplemented:
#    2709     return result
#
# File pandas/_libs/ops_dispatch.pyx:113, in pandas._libs.ops_dispatch.maybe_dispatch_ufunc_to_dunder_op()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:202, in OpsMixin.__rsub__(self, other)
#     200 @unpack_zerodim_and_defer("__rsub__")
#     201 def __rsub__(self, other):
# --> 202     return self._arith_method(other, roperator.rsub)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\arrow\array.py:1091, in ArrowExtensionArray._arith_method(self, other, op)
#    1074 if (
#    1075     op in [operator.truediv, roperator.rtruediv]
#    1076     and isinstance(other, Path)
#    (...)   1081 ):
#    1082     # GH#61940
#    1083     return np.array(
#    1084         [
#    1085             op(x, other) if isinstance(x, str) else self.dtype.na_value
#    (...)   1088         dtype=object,
#    1089     )
# -> 1091 result = self._evaluate_op_method(other, op, ARROW_ARITHMETIC_FUNCS)
#    1092 if is_nan_na() and result.dtype.kind == "f":
#    1093     parr = result._pa_array
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\arrow\array.py:1043, in ArrowExtensionArray._evaluate_op_method(self, other, op, arrow_funcs)
#    1041     result = pc_func(self._pa_array, other)
#    1042 except pa.ArrowNotImplementedError as err:
# -> 1043     raise TypeError(self._op_method_error_message(other_original, op)) from err
#    1044 return self._from_pyarrow_array(result)
#
# TypeError: operation 'rsub' not supported for dtype 'str' with dtype 'int32'

# %% [markdown]
# Operaciones entre Series y DataFrames

# %%
# crear un DataFrame con valores aleatorios
rand_matrix = np.random.randint(10, size=(3, 4))

df = pd.DataFrame(rand_matrix, columns=list('ABCD'))

display(df)

display(df.iloc[0])
display(type(df.iloc[0]))

# restar una fila al resto del DataFrame
display(df - df.iloc[0])
display(df.sub(df.iloc[0], axis=1))

# restar por columnas
display(df.sub(df['A'], axis=0))
# Out:
#    A  B  C  D
# 0  5  8  6  0
# 1  3  5  2  5
# 2  8  6  1  6
# A    5
# B    8
# C    6
# D    0
# Name: 0, dtype: int32
# pandas.Series
#    A  B  C  D
# 0  0  0  0  0
# 1 -2 -3 -4  5
# 2  3 -2 -5  6
#    A  B  C  D
# 0  0  0  0  0
# 1 -2 -3 -4  5
# 2  3 -2 -5  6
#    A  B  C  D
# 0  0  3  1 -5
# 1  0  2 -1  2
# 2  0 -2 -7 -2

# %% [markdown]
# Pandas se basa en NumPy, np operadores binarios y unarios son aceptables

# %% [markdown]
# | Tipo | Operación | Descripción |
# |------|-----------|-------------|
# | Unario | `abs` | Valor absoluto de cada elemento |
# | | `sqrt` | Raíz cuadrada de cada elemento |
# | | `exp` | eˣ, siendo x cada elemento |
# | | `log`, `log10`, `log2` | Logaritmos en distintas bases de cada elemento |
# | | `sign` | Retorna el signo de cada elemento (-1 negativo, 0 cero, 1 positivo) |
# | | `ceil` | Redondea cada elemento por arriba |
# | | `floor` | Redondea cada elemento por abajo |
# | | `isnan` | Retorna si cada elemento es NaN |
# | | `cos`, `sin`, `tan` | Operaciones trigonométricas en cada elemento |
# | | `arccos`, `arcsin`, `arctan` | Inversas de operaciones trigonométricas |
# | Binario | `add` | Suma de dos arrays |
# | | `subtract` | Resta de dos arrays |
# | | `multiply` | Multiplicación de dos arrays |
# | | `divide` | División de dos arrays |
# | | `maximum`, `minimum` | Retorna el valor máximo/mínimo de cada pareja de elementos |
# | | `equal`, `not_equal` | Retorna la comparación (igual o no igual) de cada pareja de elementos |
# | | `greater`, `greater_equal`, `less`, `less_equal` | Retorna comparaciones (`>`, `>=`, `<`, `<=`) de cada pareja de elementos |
