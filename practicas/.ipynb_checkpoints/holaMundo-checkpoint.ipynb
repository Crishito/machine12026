# %% [markdown]
# <img src="img/logoitqv1.jpg">

# %% [markdown]
# # Primer Programa en Python
# ## Hola mundo desde Python

# %% [markdown]
# <img src="img/python_logo.png">

# %% [markdown]
# * Nombre: *Christian Zumárraga*
# * Fecha : **24-06-2026**
# * Repositorio: *<a href="https://github.com/Crishito/machine12026/blob/main/practicas/holaMundo.ipynb">Link del repositorio de GitHub</a>*
# * [https://github.com/Crishito/machine12026/blob/main/practicas/holaMundo.ipynb](https://github.com/Crishito/machine12026/blob/main/practicas/holaMundo.ipynb)

# %% [markdown]
# Esta sección es para crear una función lambda donde calculo la raíz de un número

# %%
# Comentario en python saludando desde python
print("Hola Mundo desde Python")
# Out:
# Hola Mundo desde Python
