# %%
numeros = [10, 20, 30, 40, 50, 60, 70, 80]
print(numeros[6::-2])
# Out:
# [70, 50, 30, 10]

# %%
datos = [10, -5, 20, -1, 30]

# %%
tupla = (10, 20, 30, 40)
lista=list(tupla)
lista[3]=99
tupla_nueva = tuple(lista)
print(tupla_nueva)
# Out:
# (10, 20, 30, 99)

# %%
datos = (5, 10, 15, 20, 25)
lista=list(datos)
lista[3]=0
datos_tupla = tuple(lista)
print(datos_tupla)
# Out:
# (5, 10, 15, 0, 25)

# %%
def nombre_de_la_funcion(parametro1, parametro2):
    resultado = parametro1 + parametro2
    return resultado

# %%
persona = {'Nombre': 'Carlos', 'Edad': 34}
print(persona['Nombre'])  # Acceso por clave [cite: 966]
persona['Ciudad'] = 'Quito' # Añadir un nuevo par clave-valor [cite: 985]
print(persona)
# Out:
# Carlos
# {'Nombre': 'Carlos', 'Edad': 34, 'Ciudad': 'Quito'}

# %%
print(4)
print(4,2)
print('Hello')
print(False)
# Out:
# 4
# 4 2
# Hello
# False

# %%
print([1, 2, 3])
print({'Nombre':'jairo','edad':20})
print({1, 2, 3})
print ((4, 5))
2, 4
# Out:
# [1, 2, 3]
# {'Nombre': 'jairo', 'edad': 20}
# {1, 2, 3}
# (4, 5)
# (2, 4)

# %%
a = 25
b = 25
print(id(a))
print(id(b))
print(id(25))
# Out:
# 140732417222312
# 140732417222312
# 140732417222312

# %%
a = 510
b = 510
print(id(a))
print(id(c))
print(id(4567))
# Out:
# 1800896488880
# 1800896491280
# 1800896491504

# %%
a = 4.5
z = a + 3

# %%
print(z)
# Out:
# 7.5

# %%
import random
y_data1 = np.ramdom.radint(100,size=(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 import random
# ----> 2 y_data1 = np.ramdom.radint(100,size=(10))
#
# NameError: name 'np' is not defined
